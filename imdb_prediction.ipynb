# %%
# Load and preprocess the IMDB dataset
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=10000)

# Pad sequences to ensure uniform length
maxlen = 500
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)

print(f"Training data shape: {x_train.shape}")
print(f"Testing data shape: {x_test.shape}")
# Out:
# Training data shape: (25000, 500)
# Testing data shape: (25000, 500)

# %%
# Create the SimpleRNN model with improved architecture
model = Sequential([
    Embedding(10000, 64),  # Increased embedding dimension
    SimpleRNN(64, dropout=0.2, recurrent_dropout=0.2),  # Added dropout for regularization
    Dense(32, activation='relu'),  # Added intermediate dense layer
    Dense(1, activation='sigmoid')
])

# Build the model with input shape
model.build(input_shape=(None, 500))  # 500 is our maxlen

# Compile the model with improved settings
model.compile(optimizer='adam',  # Changed to adam optimizer
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Display model summary
model.summary()
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_9 (Embedding)         │ (None, 500, 64)        │       640,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_9 (SimpleRNN)        │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 650,369 (2.48 MB)
#  Trainable params: 650,369 (2.48 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model with improved training parameters
history = model.fit(x_train, y_train,
                    epochs=15,  # Increased epochs
                    batch_size=64,  # Reduced batch size for better generalization
                    validation_split=0.2,
                    verbose=1)

# Evaluate the model on test data
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'\nTest accuracy: {test_acc:.3f}')
# Out:
# Epoch 1/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 37s 113ms/step - accuracy: 0.5120 - loss: 0.6965 - val_accuracy: 0.5358 - val_loss: 0.6888
# Epoch 2/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 35s 112ms/step - accuracy: 0.5314 - loss: 0.6894 - val_accuracy: 0.5548 - val_loss: 0.6795
# Epoch 3/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 35s 112ms/step - accuracy: 0.5590 - loss: 0.6771 - val_accuracy: 0.5612 - val_loss: 0.6690
# Epoch 4/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 34s 110ms/step - accuracy: 0.5862 - loss: 0.6631 - val_accuracy: 0.6044 - val_loss: 0.6488
# Epoch 5/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 35s 112ms/step - accuracy: 0.6110 - loss: 0.6424 - val_accuracy: 0.6038 - val_loss: 0.6414
# Epoch 6/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 35s 110ms/step - accuracy: 0.6410 - loss: 0.6228 - val_accuracy: 0.6156 - val_loss: 0.6315
# Epoch 7/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 35s 111ms/step - accuracy: 0.6557 - loss: 0.6069 - val_accuracy: 0.6534 - val_loss: 0.6025
# Epoch 8/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 35s 111ms/step - accuracy: 0.6916 - loss: 0.5719 - val_accuracy: 0.6608 - val_loss: 0.5945
# Epoch 9/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 35s 111ms/step - accuracy: 0.7060 - loss: 0.5503 - val_accuracy: 0.6582 - val_loss: 0.6044
# Epoch 10/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 35s 111ms/step - accuracy: 0.7240 - loss: 0.5292 - val_accuracy: 0.6546 - val_loss: 0.6008
# Epoch 11/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 35s 111ms/step - accuracy: 0.7127 - loss: 0.5421 - val_accuracy: 0.6374 - val_loss: 0.6120
# Epoch 12/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 35s 113ms/step - accuracy: 0.7156 - loss: 0.5402 - val_accuracy: 0.6492 - val_loss: 0.6132
# Epoch 13/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 35s 113ms/step - accuracy: 0.7207 - loss: 0.5325 - val_accuracy: 0.6658 - val_loss: 0.6049
# Epoch 14/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 35s 112ms/step - accuracy: 0.7290 - loss: 0.5182 - val_accuracy: 0.6694 - val_loss: 0.6119
# Epoch 15/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 35s 110ms/step - accuracy: 0.7407 - loss: 0.5033 - val_accuracy: 0.6704 - val_loss: 0.6106
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.6745 - loss: 0.6086
#
# Test accuracy: 0.675

# %%
# Save the trained model
model.save('simple_rnn_imdb.h5')
print("Model saved successfully!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully!

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential,load_model
from tensorflow.keras.layers import Embedding,SimpleRNN,Dense

# %%
word_index=imdb.get_word_index()
reverse_word_index={value: key for key,value in word_index.items()}

# %%
model=load_model('simple_rnn_imdb.h5')
model.summary()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ (None, 500, 128)       │     1,280,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_2 (SimpleRNN)        │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,313,027 (5.01 MB)
#  Trainable params: 1,313,025 (5.01 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
model.get_weights()
# Out:
# [array([[-0.06399251, -0.03257281,  0.07295468, ...,  0.0394618 ,
#           0.05375782,  0.04740079],
#         [-0.09777822,  0.05513681, -0.00538881, ...,  0.04694052,
#           0.03853096,  0.00588319],
#         [ 0.03616268,  0.09125412,  0.01456579, ...,  0.02248602,
#          -0.02157305,  0.03995638],
#         ...,
#         [ 0.07937548, -0.04275234,  0.01933134, ..., -0.09270284,
#          -0.05238854,  0.00417251],
#         [-0.09213   , -0.13485558, -0.07747236, ..., -0.00259153,
#          -0.05790082,  0.13588387],
#         [ 0.09953211, -0.08207335,  0.09139773, ..., -0.01613648,
#           0.02972493,  0.062899  ]], shape=(10000, 64), dtype=float32),
#  array([[-0.09233293,  0.06172058, -0.10504811, ...,  0.03728642,
#          -0.25440368,  0.07704142],
#         [ 0.18230826,  0.09765802,  0.25249586, ...,  0.07483737,
#          -0.2143968 ,  0.12827687],
#         [ 0.19180496,  0.10723943,  0.02128827, ..., -0.05598957,
#          -0.08973702, -0.06318617],
#         ...,
#         [ 0.01606019, -0.13629285, -0.20052   , ...,  0.10736358,
#           0.01179481, -0.0797194 ],
#         [ 0.17565069, -0.04683949, -0.02589333, ..., -0.06244387,
#           0.18137947, -0.24878913],
#         [ 0.07262216,  0.16863658,  0.0340196 , ..., -0.11834727,
#           0.22228949, -0.19063514]], shape=(64, 64), dtype=float32),
#  array([[-0.02655606, -0.2713086 ,  0.06433127, ...,  0.04110338,
#           0.04140919, -0.16711317],
#         [ 0.1691839 , -0.00724872,  0.14837591, ..., -0.05368023,
#          -0.2587007 ,  0.00221819],
#         [ 0.11115693,  0.04947524, -0.01989739, ..., -0.06447642,
#          -0.08858895,  0.15122846],
#         ...,
#         [-0.05640472,  0.15954606,  0.2297697 , ..., -0.09888461,
#           0.00768513, -0.17608295],
#         [ 0.00733357,  0.06349473,  0.01268514, ...,  0.15200643,
#           0.13477089, -0.01835301],
#         [-0.00354474, -0.05748128,  0.13836007, ...,  0.01536847,
#           0.12542713, -0.15856248]], shape=(64, 64), dtype=float32),
#  array([ 0.03572443,  0.0155091 , -0.05709795,  0.06013568,  0.01721363,
#         -0.0125701 ,  0.03193314, -0.03925377,  0.02060145,  0.01451246,
#          0.07598171, -0.02745301,  0.01859876,  0.0326714 ,  0.00602495,
#          0.03176538, -0.06580754,  0.07487269, -0.1014481 ,  0.02163358,
#         -0.00357194, -0.08267649, -0.02204166,  0.01567836,  0.00502396,
#         -0.01222029, -0.00642014,  0.03217161, -0.03040246,  0.00241156,
#          0.02484299, -0.01570794, -0.01910452,  0.04719352, -0.0576753 ,
#          0.04533538, -0.04399903,  0.03382311,  0.06972861, -0.08099893,
#         -0.00624875,  0.02036994,  0.00461133, -0.011613  , -0.09117947,
#          0.04151343,  0.00491597,  0.02115567,  0.08482526,  0.03928565,
#          0.02651815, -0.04002099,  0.00930303,  0.02871238,  0.01998687,
#          0.04323405, -0.09059516, -0.04311796, -0.04558986,  0.09855145,
#          0.04980001,  0.05297606,  0.06532545, -0.02962777], dtype=float32),
#  array([[ 2.2408135e-04, -2.7400157e-01, -1.8000659e-01, ...,
#          -3.9518863e-02, -1.4952604e-01,  3.0376840e-01],
#         [ 2.2985502e-01,  8.4055819e-02,  1.3423266e-01, ...,
#          -2.7765748e-01,  1.2148936e-01, -2.9506376e-01],
#         [ 1.4264174e-01,  2.9688884e-02,  1.3220063e-01, ...,
#          -5.3131878e-01,  8.2590953e-02, -1.4091657e-01],
#         ...,
#         [ 2.2793250e-02, -4.1277581e-03, -3.0965790e-01, ...,
#           8.3434932e-02, -1.4598782e-01,  2.3158409e-02],
#         [-1.3959786e-01,  1.5964651e-01,  1.4707160e-03, ...,
#           2.1238551e-02, -2.0242184e-01, -1.9415101e-01],
#         [-7.2775669e-02,  1.5754286e-02, -1.7942751e-02, ...,
#          -3.1005725e-01,  3.6076117e-02, -2.2275928e-01]],
#        shape=(64, 32), dtype=float32),
#  array([ 0.01840156,  0.10652725,  0.16879092,  0.14784701,  0.0674371 ,
#          0.20866778,  0.03660022,  0.13416071,  0.02924779,  0.13791843,
#          0.01894804,  0.29825613,  0.0025041 ,  0.18368143,  0.18463394,
#         -0.0090641 , -0.00827763,  0.04984189,  0.10713193,  0.04977412,
#          0.15455647,  0.03588085, -0.00868263,  0.07027552,  0.11707921,
#         -0.00471302,  0.07322758,  0.20083684,  0.10559302,  0.01300772,
#          0.10084458, -0.02633576], dtype=float32),
#  array([[ 0.29271716],
#         [ 0.22718994],
#         [ 0.32798004],
#         [-0.18204693],
#         [ 0.07308763],
#         [ 0.24379215],
#         [-0.21948932],
#         [ 0.29911736],
#         [-0.11959291],
#         [-0.41395298],
#         [ 0.27524748],
#         [ 0.5542067 ],
#         [-0.10583147],
#         [ 0.42854744],
#         [-0.48898718],
#         [ 0.09565547],
#         [-0.22192205],
#         [-0.28955603],
#         [ 0.20194815],
#         [ 0.41446194],
#         [ 0.4332489 ],
#         [ 0.12428166],
#         [ 0.37903318],
#         [-0.3580054 ],
#         [ 0.24321774],
#         [-0.1233077 ],
#         [ 0.26946908],
#         [ 0.26692387],
#         [-0.35036063],
#         [-0.16828094],
#         [ 0.14818364],
#         [-0.16784115]], dtype=float32),
#  array([-0.05892337], dtype=float32)]

# %%
def decode_review(encoded_review):
    return ' '.join([reverse_word_index.get(i-3,'?') for i in encoded_review])

def preprocess_text(text):
    words=text.lower().split()
    encoded_review=[word_index.get(word,2)+ 3 for word in words]
    padded_review=sequence.pad_sequences([encoded_review],maxlen=500)
    return padded_review

# %%
#prediction function
def predict_sentiment(review):
    preprocessed_input=preprocess_text(review)
    
    prediction=model.predict(preprocessed_input)
    sentiment='Positive' if prediction[0][0]>0.5 else 'Negative'
    return sentiment,prediction[0][0]

# %%
example_review="This movie was fantastic! The acting was great and the plot was thrilling."
sentiment,score=predict_sentiment(example_review)
print(f'Review:{example_review}')
print(f'Sentiment: {sentiment}')
print(f'Prediction Score: {score}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# Review:This movie was fantastic! The acting was great and the plot was thrilling.
# Sentiment: Positive
# Prediction Score: 0.6837202906608582

# %%
example_review="This movie was boring! The acting bad"
sentiment,score=predict_sentiment(example_review)
print(f'Review:{example_review}')
print(f'Sentiment: {sentiment}')
print(f'Prediction Score: {score}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Review:This movie was boring! The acting bad
# Sentiment: Negative
# Prediction Score: 0.038917504251003265
